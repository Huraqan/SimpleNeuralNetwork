# %% [markdown]
# # Single epoch comparison

# %%
import pandas as pd
import seaborn as sns
from utils.notebook_tools import side_by_side, get_win_fails, get_win_fails_by_digit, plot_win_fails

costs_normal_16_16 = pd.read_csv("reports/costs_normal_16_16.csv")
costs_normal_49_16 = pd.read_csv("reports/costs_normal_49_16.csv")
costs_noise_49_16 = pd.read_csv("reports/costs_noise_49_16.csv")

# %%
side_by_side({
    "Normal 16-16": get_win_fails(costs_normal_16_16),
    "Normal 49-16": get_win_fails(costs_normal_49_16),
    "Noise 49-16": get_win_fails(costs_noise_49_16),
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_dad4e" style='display:inline; vertical-align:top;'>
#   <caption>Normal 16-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dad4e_level0_col0" class="col_heading level0 col0" >81.71%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dad4e_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_dad4e_row0_col0" class="data row0 col0" >8171</td>
#     </tr>
#     <tr>
#       <th id="T_dad4e_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_dad4e_row1_col0" class="data row1 col0" >1829</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ead5b" style='display:inline; vertical-align:top;'>
#   <caption>Normal 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ead5b_level0_col0" class="col_heading level0 col0" >84.22%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ead5b_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_ead5b_row0_col0" class="data row0 col0" >8422</td>
#     </tr>
#     <tr>
#       <th id="T_ead5b_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_ead5b_row1_col0" class="data row1 col0" >1578</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ef007" style='display:inline; vertical-align:top;'>
#   <caption>Noise 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef007_level0_col0" class="col_heading level0 col0" >84.45%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef007_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_ef007_row0_col0" class="data row0 col0" >9289</td>
#     </tr>
#     <tr>
#       <th id="T_ef007_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_ef007_row1_col0" class="data row1 col0" >1711</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_win_fails(costs_normal_16_16)
plot_win_fails(costs_normal_49_16)
plot_win_fails(costs_noise_49_16)

# %%
side_by_side({
    "Normal 16-16": get_win_fails_by_digit(costs_normal_16_16),
    "Normal 49-16": get_win_fails_by_digit(costs_normal_49_16),
    "Noise 49-16": get_win_fails_by_digit(costs_noise_49_16),
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_41af8" style='display:inline; vertical-align:top;'>
#   <caption>Normal 16-16</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41af8_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Digit</th>
#       <th class="index_name level1" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41af8_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_41af8_level1_row0" class="row_heading level1 row0" >win</th>
#       <td id="T_41af8_row0_col0" class="data row0 col0" >905</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row1" class="row_heading level1 row1" >fail</th>
#       <td id="T_41af8_row1_col0" class="data row1 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_41af8_level1_row2" class="row_heading level1 row2" >win</th>
#       <td id="T_41af8_row2_col0" class="data row2 col0" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row3" class="row_heading level1 row3" >fail</th>
#       <td id="T_41af8_row3_col0" class="data row3 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_41af8_level1_row4" class="row_heading level1 row4" >win</th>
#       <td id="T_41af8_row4_col0" class="data row4 col0" >901</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row5" class="row_heading level1 row5" >fail</th>
#       <td id="T_41af8_row5_col0" class="data row5 col0" >131</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#       <th id="T_41af8_level1_row6" class="row_heading level1 row6" >win</th>
#       <td id="T_41af8_row6_col0" class="data row6 col0" >798</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row7" class="row_heading level1 row7" >fail</th>
#       <td id="T_41af8_row7_col0" class="data row7 col0" >212</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row8" class="row_heading level0 row8" rowspan="2">4</th>
#       <th id="T_41af8_level1_row8" class="row_heading level1 row8" >win</th>
#       <td id="T_41af8_row8_col0" class="data row8 col0" >804</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row9" class="row_heading level1 row9" >fail</th>
#       <td id="T_41af8_row9_col0" class="data row9 col0" >178</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row10" class="row_heading level0 row10" rowspan="2">5</th>
#       <th id="T_41af8_level1_row10" class="row_heading level1 row10" >win</th>
#       <td id="T_41af8_row10_col0" class="data row10 col0" >555</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row11" class="row_heading level1 row11" >fail</th>
#       <td id="T_41af8_row11_col0" class="data row11 col0" >337</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row12" class="row_heading level0 row12" rowspan="2">6</th>
#       <th id="T_41af8_level1_row12" class="row_heading level1 row12" >win</th>
#       <td id="T_41af8_row12_col0" class="data row12 col0" >844</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row13" class="row_heading level1 row13" >fail</th>
#       <td id="T_41af8_row13_col0" class="data row13 col0" >114</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row14" class="row_heading level0 row14" rowspan="2">7</th>
#       <th id="T_41af8_level1_row14" class="row_heading level1 row14" >win</th>
#       <td id="T_41af8_row14_col0" class="data row14 col0" >881</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row15" class="row_heading level1 row15" >fail</th>
#       <td id="T_41af8_row15_col0" class="data row15 col0" >147</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row16" class="row_heading level0 row16" rowspan="2">8</th>
#       <th id="T_41af8_level1_row16" class="row_heading level1 row16" >win</th>
#       <td id="T_41af8_row16_col0" class="data row16 col0" >664</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row17" class="row_heading level1 row17" >fail</th>
#       <td id="T_41af8_row17_col0" class="data row17 col0" >310</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level0_row18" class="row_heading level0 row18" rowspan="2">9</th>
#       <th id="T_41af8_level1_row18" class="row_heading level1 row18" >win</th>
#       <td id="T_41af8_row18_col0" class="data row18 col0" >717</td>
#     </tr>
#     <tr>
#       <th id="T_41af8_level1_row19" class="row_heading level1 row19" >fail</th>
#       <td id="T_41af8_row19_col0" class="data row19 col0" >292</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7232c" style='display:inline; vertical-align:top;'>
#   <caption>Normal 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7232c_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Digit</th>
#       <th class="index_name level1" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7232c_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_7232c_level1_row0" class="row_heading level1 row0" >win</th>
#       <td id="T_7232c_row0_col0" class="data row0 col0" >901</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row1" class="row_heading level1 row1" >fail</th>
#       <td id="T_7232c_row1_col0" class="data row1 col0" >79</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_7232c_level1_row2" class="row_heading level1 row2" >win</th>
#       <td id="T_7232c_row2_col0" class="data row2 col0" >1114</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row3" class="row_heading level1 row3" >fail</th>
#       <td id="T_7232c_row3_col0" class="data row3 col0" >21</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_7232c_level1_row4" class="row_heading level1 row4" >win</th>
#       <td id="T_7232c_row4_col0" class="data row4 col0" >829</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row5" class="row_heading level1 row5" >fail</th>
#       <td id="T_7232c_row5_col0" class="data row5 col0" >203</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#       <th id="T_7232c_level1_row6" class="row_heading level1 row6" >win</th>
#       <td id="T_7232c_row6_col0" class="data row6 col0" >805</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row7" class="row_heading level1 row7" >fail</th>
#       <td id="T_7232c_row7_col0" class="data row7 col0" >205</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row8" class="row_heading level0 row8" rowspan="2">4</th>
#       <th id="T_7232c_level1_row8" class="row_heading level1 row8" >win</th>
#       <td id="T_7232c_row8_col0" class="data row8 col0" >824</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row9" class="row_heading level1 row9" >fail</th>
#       <td id="T_7232c_row9_col0" class="data row9 col0" >158</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row10" class="row_heading level0 row10" rowspan="2">5</th>
#       <th id="T_7232c_level1_row10" class="row_heading level1 row10" >win</th>
#       <td id="T_7232c_row10_col0" class="data row10 col0" >692</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row11" class="row_heading level1 row11" >fail</th>
#       <td id="T_7232c_row11_col0" class="data row11 col0" >200</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level0_row12" class="row_heading level0 row12" rowspan="2">6</th>
#       <th id="T_7232c_level1_row12" class="row_heading level1 row12" >win</th>
#       <td id="T_7232c_row12_col0" class="data row12 col0" >888</td>
#     </tr>
#     <tr>
#       <th id="T_7232c_level1_row13" class="row_heading level1 row13" >fai

# %% [markdown]
# # 3 Epochs comparison

# %%
import pandas as pd
import seaborn as sns
from utils.notebook_tools import side_by_side, get_win_fails, plot_win_fails

costs_normal_3e_16_16 = pd.read_csv("reports/costs_normal_3e_16_16.csv")
costs_normal_3e_49_16 = pd.read_csv("reports/costs_normal_3e_49_16.csv")
costs_noise_3e_49_16 = pd.read_csv("reports/costs_noise_3e_49_16.csv")

# %%
side_by_side({
    "Normal 3E 16-16": get_win_fails(costs_normal_3e_16_16),
    "Normal 3E 49-16": get_win_fails(costs_normal_3e_49_16),
    "Noise 3E 49-16": get_win_fails(costs_noise_3e_49_16),
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_162f7" style='display:inline; vertical-align:top;'>
#   <caption>Normal 3E 16-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_162f7_level0_col0" class="col_heading level0 col0" >89.09%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_162f7_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_162f7_row0_col0" class="data row0 col0" >8909</td>
#     </tr>
#     <tr>
#       <th id="T_162f7_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_162f7_row1_col0" class="data row1 col0" >1091</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bde10" style='display:inline; vertical-align:top;'>
#   <caption>Normal 3E 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bde10_level0_col0" class="col_heading level0 col0" >91.44%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bde10_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_bde10_row0_col0" class="data row0 col0" >9144</td>
#     </tr>
#     <tr>
#       <th id="T_bde10_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_bde10_row1_col0" class="data row1 col0" >856</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e021a" style='display:inline; vertical-align:top;'>
#   <caption>Noise 3E 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e021a_level0_col0" class="col_heading level0 col0" >91.5%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e021a_level0_row0" class="row_heading level0 row0" >win</th>
#       <td id="T_e021a_row0_col0" class="data row0 col0" >10065</td>
#     </tr>
#     <tr>
#       <th id="T_e021a_level0_row1" class="row_heading level0 row1" >fail</th>
#       <td id="T_e021a_row1_col0" class="data row1 col0" >935</td>
#     </tr>
#   </tbody>
# </table>

# %%
side_by_side({
    "Normal 3E 16-16": get_win_fails_by_digit(costs_normal_3e_16_16),
    "Normal 3E 49-16": get_win_fails_by_digit(costs_normal_3e_49_16),
    "Noise 3E 49-16": get_win_fails_by_digit(costs_noise_3e_49_16),
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7808" style='display:inline; vertical-align:top;'>
#   <caption>Normal 3E 16-16</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7808_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Digit</th>
#       <th class="index_name level1" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7808_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_e7808_level1_row0" class="row_heading level1 row0" >win</th>
#       <td id="T_e7808_row0_col0" class="data row0 col0" >935</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row1" class="row_heading level1 row1" >fail</th>
#       <td id="T_e7808_row1_col0" class="data row1 col0" >45</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_e7808_level1_row2" class="row_heading level1 row2" >win</th>
#       <td id="T_e7808_row2_col0" class="data row2 col0" >1107</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row3" class="row_heading level1 row3" >fail</th>
#       <td id="T_e7808_row3_col0" class="data row3 col0" >28</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_e7808_level1_row4" class="row_heading level1 row4" >win</th>
#       <td id="T_e7808_row4_col0" class="data row4 col0" >908</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row5" class="row_heading level1 row5" >fail</th>
#       <td id="T_e7808_row5_col0" class="data row5 col0" >124</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#       <th id="T_e7808_level1_row6" class="row_heading level1 row6" >win</th>
#       <td id="T_e7808_row6_col0" class="data row6 col0" >877</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row7" class="row_heading level1 row7" >fail</th>
#       <td id="T_e7808_row7_col0" class="data row7 col0" >133</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row8" class="row_heading level0 row8" rowspan="2">4</th>
#       <th id="T_e7808_level1_row8" class="row_heading level1 row8" >win</th>
#       <td id="T_e7808_row8_col0" class="data row8 col0" >864</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row9" class="row_heading level1 row9" >fail</th>
#       <td id="T_e7808_row9_col0" class="data row9 col0" >118</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row10" class="row_heading level0 row10" rowspan="2">5</th>
#       <th id="T_e7808_level1_row10" class="row_heading level1 row10" >win</th>
#       <td id="T_e7808_row10_col0" class="data row10 col0" >765</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row11" class="row_heading level1 row11" >fail</th>
#       <td id="T_e7808_row11_col0" class="data row11 col0" >127</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row12" class="row_heading level0 row12" rowspan="2">6</th>
#       <th id="T_e7808_level1_row12" class="row_heading level1 row12" >win</th>
#       <td id="T_e7808_row12_col0" class="data row12 col0" >886</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row13" class="row_heading level1 row13" >fail</th>
#       <td id="T_e7808_row13_col0" class="data row13 col0" >72</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row14" class="row_heading level0 row14" rowspan="2">7</th>
#       <th id="T_e7808_level1_row14" class="row_heading level1 row14" >win</th>
#       <td id="T_e7808_row14_col0" class="data row14 col0" >920</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row15" class="row_heading level1 row15" >fail</th>
#       <td id="T_e7808_row15_col0" class="data row15 col0" >108</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row16" class="row_heading level0 row16" rowspan="2">8</th>
#       <th id="T_e7808_level1_row16" class="row_heading level1 row16" >win</th>
#       <td id="T_e7808_row16_col0" class="data row16 col0" >796</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row17" class="row_heading level1 row17" >fail</th>
#       <td id="T_e7808_row17_col0" class="data row17 col0" >178</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level0_row18" class="row_heading level0 row18" rowspan="2">9</th>
#       <th id="T_e7808_level1_row18" class="row_heading level1 row18" >win</th>
#       <td id="T_e7808_row18_col0" class="data row18 col0" >851</td>
#     </tr>
#     <tr>
#       <th id="T_e7808_level1_row19" class="row_heading level1 row19" >fail</th>
#       <td id="T_e7808_row19_col0" class="data row19 col0" >158</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_37d31" style='display:inline; vertical-align:top;'>
#   <caption>Normal 3E 49-16</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37d31_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Digit</th>
#       <th class="index_name level1" >Win or Fail</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37d31_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_37d31_level1_row0" class="row_heading level1 row0" >win</th>
#       <td id="T_37d31_row0_col0" class="data row0 col0" >947</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row1" class="row_heading level1 row1" >fail</th>
#       <td id="T_37d31_row1_col0" class="data row1 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_37d31_level1_row2" class="row_heading level1 row2" >win</th>
#       <td id="T_37d31_row2_col0" class="data row2 col0" >1113</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row3" class="row_heading level1 row3" >fail</th>
#       <td id="T_37d31_row3_col0" class="data row3 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_37d31_level1_row4" class="row_heading level1 row4" >win</th>
#       <td id="T_37d31_row4_col0" class="data row4 col0" >933</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row5" class="row_heading level1 row5" >fail</th>
#       <td id="T_37d31_row5_col0" class="data row5 col0" >99</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#       <th id="T_37d31_level1_row6" class="row_heading level1 row6" >win</th>
#       <td id="T_37d31_row6_col0" class="data row6 col0" >894</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row7" class="row_heading level1 row7" >fail</th>
#       <td id="T_37d31_row7_col0" class="data row7 col0" >116</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row8" class="row_heading level0 row8" rowspan="2">4</th>
#       <th id="T_37d31_level1_row8" class="row_heading level1 row8" >win</th>
#       <td id="T_37d31_row8_col0" class="data row8 col0" >918</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row9" class="row_heading level1 row9" >fail</th>
#       <td id="T_37d31_row9_col0" class="data row9 col0" >64</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row10" class="row_heading level0 row10" rowspan="2">5</th>
#       <th id="T_37d31_level1_row10" class="row_heading level1 row10" >win</th>
#       <td id="T_37d31_row10_col0" class="data row10 col0" >789</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row11" class="row_heading level1 row11" >fail</th>
#       <td id="T_37d31_row11_col0" class="data row11 col0" >103</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level0_row12" class="row_heading level0 row12" rowspan="2">6</th>
#       <th id="T_37d31_level1_row12" class="row_heading level1 row12" >win</th>
#       <td id="T_37d31_row12_col0" class="data row12 col0" >885</td>
#     </tr>
#     <tr>
#       <th id="T_37d31_level1_row13" class="row_heading level1 row13" >

# %%
plot_win_fails(costs_normal_3e_16_16)
plot_win_fails(costs_normal_3e_49_16)
plot_win_fails(costs_noise_3e_49_16)
